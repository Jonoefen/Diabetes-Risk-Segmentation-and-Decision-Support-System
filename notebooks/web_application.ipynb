# %% [markdown]
# # Phase 6: Web Application
#
# The app is implemented in `src/web_app.py`. Run the install cell if needed, then run the last cell to start the server.

# %%
# Install dependencies (run once per environment)
# !pip install dash plotly
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# The Dash app lives in `src/web_app.py` — edit that file.
# Dependencies: pip install dash plotly
from pathlib import Path
app_file = Path('..') / 'src' / 'web_app.py'
print('App file:', app_file)
assert app_file.exists(), 'src/web_app.py not found'
# Out:
# App file: ..\src\web_app.py

# %%
# Run the Dash web app (stop the cell to stop server)
# !python ../src/web_app.py
# Out:
# ^C
